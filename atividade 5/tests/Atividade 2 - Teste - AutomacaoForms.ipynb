# %%
import pyautogui
import time

pyautogui.hotkey('ctrl', 'tab')
time.sleep(0.5)
pyautogui.press('tab')
time.sleep(1)

pyautogui.write('Teste com campo vazio', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu@Email.com', interval=0.1)
time.sleep(1)
pyautogui.press('tab', presses=2, interval=0.4)
time.sleep(1)
pyautogui.press('enter')
time.sleep(1)


time.sleep(3)
pyautogui.hotkey('shift', 'tab')
time.sleep(1)

pyautogui.write('Teste com caracteres especiais', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('><.,;/|^`´~"}{][?°ºª:=+!@#$%¨*()_-&', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu@Email.com', interval=0.1)
time.sleep(1)
pyautogui.press('tab', presses=2, interval=0.4)
time.sleep(1)
pyautogui.press('enter')

time.sleep(3)
pyautogui.hotkey('shift', 'tab')
time.sleep(1)

pyautogui.write('Teste com letras', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu cpf', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu@Email.com', interval=0.1)
time.sleep(1)
pyautogui.press('tab', presses=2, interval=0.4)
time.sleep(1)
pyautogui.press('enter')

time.sleep(3)
pyautogui.hotkey('shift', 'tab')
time.sleep(1)

pyautogui.write('Teste com numeros aleatorios', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('12345678912', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu@Email.com', interval=0.1)
time.sleep(1)
pyautogui.press('tab', presses=2, interval=0.4)
time.sleep(1)
pyautogui.press('enter')

time.sleep(1.5)

pyautogui.press('enter')
time.sleep(0.3)
pyautogui.hotkey('shift', 'tab')
time.sleep(0.3)
pyautogui.hotkey('shift', 'tab')
time.sleep(0.3)
pyautogui.hotkey('shift', 'tab')
time.sleep(0.3)
pyautogui.hotkey('shift', 'tab')

time.sleep(1)

pyautogui.write('Teste com cpf valido', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('11111111111', interval=0.1)
time.sleep(1)
pyautogui.press('tab')
time.sleep(0.5)
pyautogui.write('Meu@Email.com', interval=0.1)
time.sleep(1)
pyautogui.press('tab', presses=2, interval=0.4)
time.sleep(1)
pyautogui.press('enter')
